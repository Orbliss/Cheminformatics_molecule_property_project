# %%
import deepchem as dc
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from tqdm import tqdm

# Helper function to combine ECFP and SMILES datasets
def dataset_to_df_with_smiles(ecfp_dataset, raw_dataset, tasks):
    X_list, y_list, ids_list, smiles_list = [], [], [], []
    
    # Iterate through both datasets in parallel
    for (X_batch, y_batch, w_batch, ids_batch), (X_raw, _, _, _) in zip(
        ecfp_dataset.iterbatches(batch_size=128, pad_batches=False),
        raw_dataset.iterbatches(batch_size=128, pad_batches=False)
    ):
        X_list.append(X_batch)
        y_list.append(y_batch)
        ids_list.extend(ids_batch)
        smiles_list.extend(X_raw)  # SMILES strings are in the raw features

    # Stack numerical and label arrays
    X_all = np.vstack(X_list)
    y_all = np.vstack(y_list)

    # Create DataFrames
    df_X = pd.DataFrame(X_all, columns=[f"fp_{i}" for i in range(X_all.shape[1])])
    df_y = pd.DataFrame(y_all, columns=tasks)
    df_y["mol_id"] = ids_list
    df_y["smiles"] = smiles_list

    # Combine all information into a single DataFrame
    df = pd.concat([df_y, df_X], axis=1)
    return df


# Load SIDER dataset with ECFP features (for model input)
tasks, datasets, transformers = dc.molnet.load_sider(featurizer='ECFP', splitter='scaffold')
train_ecfp, valid_ecfp, test_ecfp = datasets

# Load SIDER dataset again with raw SMILES (for visualization / metadata)
_, datasets_raw, _ = dc.molnet.load_sider(featurizer='Raw', splitter='scaffold')
train_raw, valid_raw, test_raw = datasets_raw

# Convert both representations to DataFrames
df_train = dataset_to_df_with_smiles(train_ecfp, train_raw, tasks)
df_valid = dataset_to_df_with_smiles(valid_ecfp, valid_raw, tasks)
df_test  = dataset_to_df_with_smiles(test_ecfp,  test_raw,  tasks)

feature_cols = [col for col in df_train.columns if col.startswith("fp_")]
label_cols = [col for col in df_train.columns if col not in feature_cols + ['mol_id', 'smiles', 'scaffold']]

X_train = df_train[feature_cols].astype(float).values
y_train = df_train[label_cols].astype(float).values

X_valid = df_valid[feature_cols].astype(float).values
y_valid = df_valid[label_cols].astype(float).values

X_test = df_test[feature_cols].astype(float).values
y_test = df_test[label_cols].astype(float).values

pca = PCA().fit(X_train)
cumulative_variance = pca.explained_variance_ratio_.cumsum()

# Number of components to reach 80% variance
n_components_80 = np.argmax(cumulative_variance >= 0.80) + 1

pca = PCA(n_components=n_components_80)
X_train_pca = pca.fit_transform(X_train)
X_valid_pca = pca.transform(X_valid)
X_test_pca = pca.transform(X_test)

# %%
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score, roc_auc_score
)

def evaluate_multilabel_model(y_true, y_pred, y_prob=None, name=None):
    """
    Evaluate multilabel classification performance.
    
    Parameters
    ----------
    y_true : np.ndarray
        Ground-truth binary matrix (n_samples x n_labels)
    y_pred : np.ndarray
        Predicted binary matrix (same shape as y_true)
    y_prob : np.ndarray, optional
        Predicted probabilities (for ROC-AUC if available)
    name : str
        Name of the dataframe evaluated
    """

    metrics = {"Nom :": name}
    metrics["Subset accuracy"] = accuracy_score(y_true, y_pred)
    metrics["Hamming loss"] = hamming_loss(y_true, y_pred)
    metrics["Micro F1"] = f1_score(y_true, y_pred, average="micro")
    metrics["Macro F1"] = f1_score(y_true, y_pred, average="macro")
    metrics["Weighted F1"] = f1_score(y_true, y_pred, average="weighted")
    
    if y_prob is not None:
        try:
            metrics["Micro ROC-AUC"] = roc_auc_score(y_true, y_prob, average="micro")
            metrics["Macro ROC-AUC"] = roc_auc_score(y_true, y_prob, average="macro")
        except ValueError:
            metrics["Micro ROC-AUC"] = np.nan
            metrics["Macro ROC-AUC"] = np.nan

    print("\n📊 Multilabel Evaluation Metrics:")
    for k, v in metrics.items():
        if isinstance(v, float):
            print(f"{k:20s}: {v:.4f}")
        else:
            print(f"{k:20s}: {v}")

    return metrics

# %% [markdown]
# 1. XGBoost with raw data

# %%
# Importations needed
import xgboost as xgb
from sklearn.multiclass import OneVsRestClassifier


# --- Reuse Raw ECFP Data ---
# (Ensure X_train_raw, y_train, X_valid_raw, y_valid, X_test_raw, y_test are available from the previous L1 LR cell)
# feature_cols = [col for col in df_train.columns if col.startswith("fp_")]
# label_cols = [col for col in df_train.columns if col not in feature_cols + ['mol_id', 'smiles', 'scaffold']]
# X_train_raw = df_train[feature_cols].astype(float).values
# y_train = df_train[label_cols].astype(float).values
# ... and so on for valid and test sets ...

# --- Evaluation Function (ensure it's defined) ---
# def evaluate_multilabel_model(...): ...

# --- Train XGBoost Model (Option 1) ---
print("🚀 Training XGBoost model (OneVsRestClassifier, no explicit weights)...")

# Define the XGBoost classifier
# Use eval_metric='logloss' and use_label_encoder=False as recommended for newer versions
xgb_clf = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False, random_state=42)

# Wrap it with OneVsRestClassifier
ovr_xgb_model = OneVsRestClassifier(xgb_clf, n_jobs=4) # Use n_jobs=-1 for parallel training of binary classifiers

# Train the model
ovr_xgb_model.fit(X_train, y_train)

# --- Predictions ---
print("⚙️ Generating predictions...")
y_train_pred_xgb = ovr_xgb_model.predict(X_train)
y_valid_pred_xgb = ovr_xgb_model.predict(X_valid)
y_test_pred_xgb = ovr_xgb_model.predict(X_test)

# Probabilities are needed for ROC-AUC
y_train_prob_xgb = ovr_xgb_model.predict_proba(X_train)
y_valid_prob_xgb = ovr_xgb_model.predict_proba(X_valid)
y_test_prob_xgb = ovr_xgb_model.predict_proba(X_test)

# --- Evaluation ---
print("\n=== XGBoost (OneVsRest, No Weights) Evaluation ===")
metrics_train_xgb1 = evaluate_multilabel_model(y_train, y_train_pred_xgb, y_train_prob_xgb, "Train (XGB OvR)")
metrics_valid_xgb1 = evaluate_multilabel_model(y_valid, y_valid_pred_xgb, y_valid_prob_xgb, "Validation (XGB OvR)")
metrics_test_xgb1 = evaluate_multilabel_model(y_test, y_test_pred_xgb, y_test_prob_xgb, "Test (XGB OvR)")
# Out:
# 🚀 Training XGBoost model (OneVsRestClassifier, no explicit weights)...
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [09:29:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ⚙️ Generating predictions...
#
# === XGBoost (OneVsRest, No Weights) Evaluation ===
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Train (XGB OvR)
# Subset accuracy     : 0.7318
# Hamming loss        : 0.0240
# Micro F1            : 0.9787
# Macro F1            : 0.9723
# Weighted F1         : 0.9785
# Micro ROC-AUC       : 0.9974
# Macro ROC-AUC       : 0.9971
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Validation (XGB OvR)
# Subset accuracy     : 0.0210
# Hamming loss        : 0.2313
# Micro F1            : 0.8167
# Macro F1            : 0.6629
# Weighted F1         : 0.8047
# Micro ROC-AUC       : 0.8264
# Macro ROC-AUC       : 0.5918
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Test (XGB OvR)
# Subset accuracy     : 0.0070
# Hamming loss        : 0.2481
# Micro F1            : 0.7934
# Macro F1            : 0.6364
# Weighted F1         : 0.7907
# Micro ROC-AUC       : 0.8225
# Macro ROC-AUC       : 0.6153

# %%
# --- Entraînement des modèles XGBoost (Option 2 : Individuels avec poids) ---
print("🚀 Training individual XGBoost models with scale_pos_weight")

n_samples_train = X_train.shape[0]
n_labels = y_train.shape[1]
trained_models_weighted = [] # Liste pour stocker les modèles entraînés

# Boucle sur chaque label pour entraîner un modèle spécifique
for i in tqdm(range(n_labels), desc="Training models per label"):
    y_train_label = y_train[:, i] # Sélectionne la colonne du label i

    # Calcule scale_pos_weight pour ce label
    n_positives = np.sum(y_train_label == 1)
    n_negatives = n_samples_train - n_positives
    # Gère le cas où il n'y a que des 0 ou que des 1 (peu probable mais sûr)
    scale_pos_weight = n_negatives / n_positives if n_positives > 0 and n_negatives > 0 else 1

    # Définit le classifieur XGBoost AVEC le poids calculé
    xgb_clf_weighted = xgb.XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',
        use_label_encoder=False,
        scale_pos_weight=scale_pos_weight, # <<< Poids spécifique à ce label
        random_state=42,
        # Tu peux ajouter n_jobs=1 ici si tu veux limiter l'utilisation du CPU par modèle
        # n_jobs=1
    )

    # Entraîne le modèle pour ce label
    xgb_clf_weighted.fit(X_train, y_train_label)
    trained_models_weighted.append(xgb_clf_weighted)

# --- Prédictions en utilisant la liste des modèles entraînés ---
print("⚙️ Generating predictions from individual weighted models...")

# Fonction pour prédire avec la liste de modèles (peut être réutilisée)
def predict_individual_models(X, models):
    n_samples_pred = X.shape[0]
    n_labels_pred = len(models)
    # Initialise les matrices pour les prédictions binaires et les probabilités
    y_pred = np.zeros((n_samples_pred, n_labels_pred))
    y_prob = np.zeros((n_samples_pred, n_labels_pred))

    # Boucle sur chaque modèle (correspondant à un label)
    for i, model in enumerate(models):
        probas = model.predict_proba(X) # Probabilités [classe 0, classe 1]
        y_prob[:, i] = probas[:, 1]      # Stocke la probabilité de la classe positive (1)
        y_pred[:, i] = (probas[:, 1] >= 0.5).astype(int) # Prédit 1 si proba >= 0.5

    return y_pred, y_prob

# Génère les prédictions pour chaque set
y_train_pred_xgb_w, y_train_prob_xgb_w = predict_individual_models(X_train, trained_models_weighted)
y_valid_pred_xgb_w, y_valid_prob_xgb_w = predict_individual_models(X_valid, trained_models_weighted)
y_test_pred_xgb_w, y_test_prob_xgb_w = predict_individual_models(X_test, trained_models_weighted)

# --- Évaluation ---
print("\n=== XGBoost (Individual Models with Weights) Evaluation ===")
metrics_train_xgb2 = evaluate_multilabel_model(y_train, y_train_pred_xgb_w, y_train_prob_xgb_w, "Train (XGB Weighted)")
metrics_valid_xgb2 = evaluate_multilabel_model(y_valid, y_valid_pred_xgb_w, y_valid_prob_xgb_w, "Validation (XGB Weighted)")
metrics_test_xgb2 = evaluate_multilabel_model(y_test, y_test_pred_xgb_w, y_test_prob_xgb_w, "Test (XGB Weighted)")
# Out:
# 🚀 Training individual XGBoost models with scale_pos_weight...
# Training models per label:   0%|                                                                                   | 0/27 [00:00<?, ?it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:09:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:   4%|██▊                                                                        | 1/27 [00:00<00:12,  2.03it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:09:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:  15%|███████████                                                                | 4/27 [00:01<00:07,  2.96it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:09:58] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:  30%|██████████████████████▏                                                    | 8/27 [00:02<00:05,  3.26it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:09:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:  44%|████████████████████████████████▉                                         | 12/27 [00:03<00:04,  3.69it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:10:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:  59%|███████████████████████████████████████████▊                              | 16/27 [00:04<00:02,  3.86it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:10:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:  70%|████████████████████████████████████████████████████                      | 19/27 [00:05<00:02,  3.58it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:10:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:  81%|████████████████████████████████████████████████████████████▎             | 22/27 [00:06<00:01,  3.20it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:10:03] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label:  96%|███████████████████████████████████████████████████████████████████████▎  | 26/27 [00:07<00:00,  3.72it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:10:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label: 100%|██████████████████████████████████████████████████████████████████████████| 27/27 [00:07<00:00,  3.42it/s]
# ⚙️ Generating predictions from individual weighted models...
#
# === XGBoost (Individual Models with Weights) Evaluation ===
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Train (XGB Weighted)
# Subset accuracy     : 0.6328
# Hamming loss        : 0.0439
# Micro F1            : 0.9596
# Macro F1            : 0.9652
# Weighted F1         : 0.9595
# Micro ROC-AUC       : 0.9939
# Macro ROC-AUC       : 0.9944
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Validation (XGB Weighted)
# Subset accuracy     : 0.0140
# Hamming loss        : 0.2587
# Micro F1            : 0.7893
# Macro F1            : 0.6555
# Weighted F1         : 0.7850
# Micro ROC-AUC       : 0.8032
# Macro ROC-AUC       : 0.5862
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Test (XGB Weighted)
# Subset accuracy     : 0.0000
# Hamming loss        : 0.2717
# Micro F1            : 0.7700
# Macro F1            : 0.6379
# Weighted F1         : 0.7756
# Micro ROC-AUC       : 0.7998
# Macro ROC-AUC       : 0.6270

# %% [markdown]
# 2. XGBoost with PCA Data

# %%
# Importations nécessaires (si pas déjà faites)
import xgboost as xgb
from sklearn.multiclass import OneVsRestClassifier
# Assurez-vous que X_train_pca, y_train, X_valid_pca, y_valid, X_test_pca, y_test sont disponibles
# Assurez-vous que la fonction evaluate_multilabel_model est définie

# --- Entraîner le modèle XGBoost sur les données PCA ---
print("🚀 Training XGBoost model (OneVsRestClassifier, no explicit weights) on PCA data...")

# Définit le classifieur XGBoost (identique à avant)
xgb_clf_pca = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False, random_state=42)

# Wrapper OneVsRestClassifier
ovr_xgb_model_pca = OneVsRestClassifier(xgb_clf_pca, n_jobs=4) # Gardons n_jobs=4 comme tu l'as utilisé

# Entraîne sur les données PCA
ovr_xgb_model_pca.fit(X_train_pca, y_train)

# --- Prédictions sur les données PCA ---
print("⚙️ Generating predictions on PCA data...")
y_train_pred_xgb_pca = ovr_xgb_model_pca.predict(X_train_pca)
y_valid_pred_xgb_pca = ovr_xgb_model_pca.predict(X_valid_pca)
y_test_pred_xgb_pca = ovr_xgb_model_pca.predict(X_test_pca)

# Probabilités pour ROC-AUC
y_train_prob_xgb_pca = ovr_xgb_model_pca.predict_proba(X_train_pca)
y_valid_prob_xgb_pca = ovr_xgb_model_pca.predict_proba(X_valid_pca)
y_test_prob_xgb_pca = ovr_xgb_model_pca.predict_proba(X_test_pca)

# --- Évaluation ---
print("\n=== XGBoost (OneVsRest, No Weights) on PCA Data Evaluation ===")
metrics_train_xgb_pca = evaluate_multilabel_model(y_train, y_train_pred_xgb_pca, y_train_prob_xgb_pca, "Train (XGB OvR PCA)")
metrics_valid_xgb_pca = evaluate_multilabel_model(y_valid, y_valid_pred_xgb_pca, y_valid_prob_xgb_pca, "Validation (XGB OvR PCA)")
metrics_test_xgb_pca = evaluate_multilabel_model(y_test, y_test_pred_xgb_pca, y_test_prob_xgb_pca, "Test (XGB OvR PCA)")
# Out:
# 🚀 Training XGBoost model (OneVsRestClassifier, no explicit weights) on PCA data...
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:31] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:43] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:47] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:50] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:51] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:19:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ⚙️ Generating predictions on PCA data...
#
# === XGBoost (OneVsRest, No Weights) on PCA Data Evaluation ===
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Train (XGB OvR PCA)
# Subset accuracy     : 0.9939
# Hamming loss        : 0.0007
# Micro F1            : 0.9994
# Macro F1            : 0.9994
# Weighted F1         : 0.9994
# Micro ROC-AUC       : 1.0000
# Macro ROC-AUC       : 1.0000
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Validation (XGB OvR PCA)
# Subset accuracy     : 0.0070
# Hamming loss        : 0.2248
# Micro F1            : 0.8220
# Macro F1            : 0.6423
# Weighted F1         : 0.8004
# Micro ROC-AUC       : 0.8270
# Macro ROC-AUC       : 0.5537
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Test (XGB OvR PCA)
# Subset accuracy     : 0.0070
# Hamming loss        : 0.2349
# Micro F1            : 0.8048
# Macro F1            : 0.6253
# Weighted F1         : 0.7902
# Micro ROC-AUC       : 0.8262
# Macro ROC-AUC       : 0.5891

# %%
# Importations needed (ensure they are loaded)
import xgboost as xgb
from sklearn.metrics import accuracy_score, hamming_loss, f1_score, roc_auc_score
import numpy as np
import pandas as pd
from tqdm import tqdm

# --- Use PCA-reduced Data ---
# (Ensure X_train_pca, y_train, X_valid_pca, y_valid, X_test_pca, y_test are available)
# These should have been created in a previous cell (around cell ID 14266b9c)

# --- Evaluation Function (ensure it's defined) ---
# def evaluate_multilabel_model(...): ...

# --- Train XGBoost Models (Option 2: Individual models with weights on PCA data) ---
print("🚀 Training individual XGBoost models with scale_pos_weight on PCA data...")

n_samples_train = X_train_pca.shape[0] # Use PCA data shape here
n_labels = y_train.shape[1]
trained_models_weighted_pca = [] # List for storing these models

# Loop over each label
for i in tqdm(range(n_labels), desc="Training models per label (PCA)"):
    y_train_label = y_train[:, i] # Weights are based on original labels

    # Calculate scale_pos_weight for the current label using y_train
    n_positives = np.sum(y_train_label == 1)
    n_negatives = n_samples_train - n_positives
    scale_pos_weight = n_negatives / n_positives if n_positives > 0 and n_negatives > 0 else 1

    # Define the XGBoost classifier WITH the calculated weight
    xgb_clf_weighted_pca = xgb.XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',
        use_label_encoder=False,
        scale_pos_weight=scale_pos_weight, # Specific weight for this label
        random_state=42,
        # n_jobs=1 # Optional: limit CPU per model if needed
    )

    # Train the model for this label ON PCA DATA
    xgb_clf_weighted_pca.fit(X_train_pca, y_train_label)
    trained_models_weighted_pca.append(xgb_clf_weighted_pca)

# --- Predictions using individual weighted models on PCA data ---
print("⚙️ Generating predictions from individual weighted models on PCA data...")

# Use the same prediction function as before
# def predict_individual_models(X, models): ...

# Generate predictions for each PCA dataset
y_train_pred_xgb_w_pca, y_train_prob_xgb_w_pca = predict_individual_models(X_train_pca, trained_models_weighted_pca)
y_valid_pred_xgb_w_pca, y_valid_prob_xgb_w_pca = predict_individual_models(X_valid_pca, trained_models_weighted_pca)
y_test_pred_xgb_w_pca, y_test_prob_xgb_w_pca = predict_individual_models(X_test_pca, trained_models_weighted_pca)

# --- Evaluation ---
print("\n=== XGBoost (Individual Models with Weights) on PCA Data Evaluation ===")
metrics_train_xgb_pca2 = evaluate_multilabel_model(y_train, y_train_pred_xgb_w_pca, y_train_prob_xgb_w_pca, "Train (XGB Weighted PCA)")
metrics_valid_xgb_pca2 = evaluate_multilabel_model(y_valid, y_valid_pred_xgb_w_pca, y_valid_prob_xgb_w_pca, "Validation (XGB Weighted PCA)")
metrics_test_xgb_pca2 = evaluate_multilabel_model(y_test, y_test_pred_xgb_w_pca, y_test_prob_xgb_w_pca, "Test (XGB Weighted PCA)")
# Out:
# 🚀 Training individual XGBoost models with scale_pos_weight on PCA data...
# Training models per label (PCA):   0%|                                                                             | 0/27 [00:00<?, ?it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):   4%|██▌                                                                  | 1/27 [00:01<00:46,  1.80s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):   7%|█████                                                                | 2/27 [00:03<00:39,  1.59s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  11%|███████▋                                                             | 3/27 [00:03<00:26,  1.11s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  15%|██████████▏                                                          | 4/27 [00:05<00:29,  1.29s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:11] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  19%|████████████▊                                                        | 5/27 [00:06<00:30,  1.38s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  22%|███████████████▎                                                     | 6/27 [00:08<00:28,  1.38s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  26%|█████████████████▉                                                   | 7/27 [00:08<00:23,  1.15s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  30%|████████████████████▍                                                | 8/27 [00:10<00:23,  1.21s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:16] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  33%|███████████████████████                                              | 9/27 [00:11<00:24,  1.34s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  41%|███████████████████████████▋                                        | 11/27 [00:13<00:18,  1.14s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  44%|██████████████████████████████▏                                     | 12/27 [00:14<00:14,  1.01it/s]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:20] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  48%|████████████████████████████████▋                                   | 13/27 [00:15<00:15,  1.10s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:21] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  52%|███████████████████████████████████▎                                | 14/27 [00:16<00:14,  1.14s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  56%|█████████████████████████████████████▊                              | 15/27 [00:18<00:13,  1.15s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  59%|████████████████████████████████████████▎                           | 16/27 [00:19<00:13,  1.26s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  63%|██████████████████████████████████████████▊                         | 17/27 [00:20<00:11,  1.12s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  67%|█████████████████████████████████████████████▎                      | 18/27 [00:21<00:10,  1.21s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  70%|███████████████████████████████████████████████▊                    | 19/27 [00:23<00:10,  1.25s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  74%|██████████████████████████████████████████████████▎                 | 20/27 [00:24<00:08,  1.28s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  78%|████████████████████████████████████████████████████▉               | 21/27 [00:25<00:08,  1.34s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  81%|███████████████████████████████████████████████████████▍            | 22/27 [00:27<00:07,  1.45s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  85%|█████████████████████████████████████████████████████████▉          | 23/27 [00:28<00:05,  1.36s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:35] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  89%|████████████████████████████████████████████████████████████▍       | 24/27 [00:30<00:04,  1.49s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA):  93%|██████████████████████████████████████████████████████████████▉     | 25/27 [00:31<00:02,  1.46s/it]/home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [11:21:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training models per label (PCA): 100%|████████████████████████████████████████████████████████████████████| 27/27 [00:33<00:00,  1.26s/it]
# ⚙️ Generating predictions from individual weighted models on PCA data...
#
# === XGBoost (Individual Models with Weights) on PCA Data Evaluation ===
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Train (XGB Weighted PCA)
# Subset accuracy     : 0.9947
# Hamming loss        : 0.0007
# Micro F1            : 0.9994
# Macro F1            : 0.9994
# Weighted F1         : 0.9994
# Micro ROC-AUC       : 1.0000
# Macro ROC-AUC       : 1.0000
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Validation (XGB Weighted PCA)
# Subset accuracy     : 0.0140
# Hamming loss        : 0.2354
# Micro F1            : 0.8107
# Macro F1            : 0.6440
# Weighted F1         : 0.7935
# Micro ROC-AUC       : 0.8189
# Macro ROC-AUC       : 0.5643
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Test (XGB Weighted PCA)
# Subset accuracy     : 0.0000
# Hamming loss        : 0.2453
# Micro F1            : 0.7945
# Macro F1            : 0.6444
# Weighted F1         : 0.7872
# Micro ROC-AUC       : 0.8131
# Macro ROC-AUC       : 0.5931

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# --- Définir l'estimateur de base ---
# Note: On ne met pas n_jobs ici, RandomizedSearchCV s'en chargera
xgb_base = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    use_label_encoder=False,
    random_state=42
)
ovr_xgb_estimator = OneVsRestClassifier(xgb_base) # Pas de n_jobs ici

# --- Définir l'espace de recherche des hyperparamètres ---
# Paramètres pour XGBClassifier à l'intérieur de OneVsRestClassifier
param_distributions_xgb = {
    'estimator__n_estimators': randint(100, 400),       # Nombre d'arbres
    'estimator__max_depth': randint(3, 10),            # Profondeur max (limite l'overfitting)
    'estimator__learning_rate': uniform(0.01, 0.2),    # Taux d'apprentissage
    'estimator__subsample': uniform(0.6, 0.4),         # Fraction d'échantillons par arbre
    'estimator__colsample_bytree': uniform(0.6, 0.4),  # Fraction de features par arbre
    'estimator__gamma': uniform(0, 0.5),               # Régularisation (min_split_loss)
    'estimator__reg_alpha': uniform(0, 1),             # Régularisation L1 (alpha)
    'estimator__reg_lambda': uniform(0, 1)             # Régularisation L2 (lambda)
    # scale_pos_weight n'est pas inclus ici car difficile à optimiser globalement via OneVsRest
}

# --- Configuration de RandomizedSearchCV ---
# Utilisation de f1_macro pour l'évaluation, sensible à l'imbalance
random_search_xgb = RandomizedSearchCV(
    estimator=ovr_xgb_estimator,
    param_distributions=param_distributions_xgb,
    n_iter=25,          # Nombre de combinaisons à tester (augmente si temps/ressources ok)
    scoring='f1_macro',
    cv=3,               # Validation croisée 3 plis
    verbose=2,
    random_state=42,
    n_jobs=4            # Nombre de coeurs à utiliser pour la recherche (ajuste selon ta machine)
)

print("🚀 Lancement de RandomizedSearchCV pour XGBoost (sur PCA)...")

# --- Lancer la recherche ---
# Important: Fournir les données de validation pour l'Early Stopping
# Note: RandomizedSearchCV ne supporte pas nativement l'early stopping direct via OneVsRestClassifier.
# L'early stopping devrait être implémenté dans une boucle personnalisée si nécessaire,
# ou on se fie à la CV pour choisir des paramètres qui généralisent bien.
# Pour simplifier, nous allons omettre l'early stopping direct ici et nous fier à la CV.
random_search_xgb.fit(X_train_pca, y_train)

# --- Afficher les meilleurs résultats ---
print("\n✅ Meilleurs paramètres trouvés pour XGBoost (sur PCA):")
print(random_search_xgb.best_params_)
print(f"\n🏆 Meilleur score F1-macro (CV) : {random_search_xgb.best_score_:.4f}")

# --- Évaluer le meilleur modèle XGBoost trouvé sur le Test set ---
best_xgb_model_pca = random_search_xgb.best_estimator_

print("\n⚙️ Génération des prédictions du meilleur modèle XGBoost (sur PCA)...")
y_test_pred_best_xgb_pca = best_xgb_model_pca.predict(X_test_pca)
y_test_prob_best_xgb_pca = best_xgb_model_pca.predict_proba(X_test_pca)

print("\n=== Évaluation du Meilleur XGBoost (RandomSearch) sur Test (PCA) ===")
metrics_test_best_xgb_pca = evaluate_multilabel_model(
    y_test, y_test_pred_best_xgb_pca, y_test_prob_best_xgb_pca, "Test (Best XGB PCA)"
)
# Out:
# 🚀 Lancement de RandomizedSearchCV pour XGBoost (sur PCA)...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:31] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:35] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:37] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:37] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:43] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:43] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:50] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:50] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:58] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:58] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:08:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:05] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:05] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:17] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:17] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:21] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:37] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:50] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:09:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:03] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:31] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:31] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:35] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:43] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:47] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:51] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:10:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:11:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:11:01] WARNING: /workspace/src/learner.cc:790:
# ...
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:37] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:37] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:43] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:47] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:58] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:52:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:11] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:17] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:21] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:43] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:47] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:51] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/rblouin/miniconda3/envs/cheminformatics_project/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:53:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Meilleurs paramètres trouvés pour XGBoost (sur PCA):
# {'estimator__colsample_bytree': np.float64(0.8989280440549523), 'estimator__gamma': np.float64(0.2698460661945399), 'estimator__learning_rate': np.float64(0.12735023313276966), 'estimator__max_depth': 3, 'estimator__n_estimators': 351, 'estimator__reg_alpha': np.float64(0.6070342476866847), 'estimator__reg_lambda': np.float64(0.27599918202254337), 'estimator__subsample': np.float64(0.718509402281633)}
#
# 🏆 Meilleur score F1-macro (CV) : 0.6274
#
# ⚙️ Génération des prédictions du meilleur modèle XGBoost (sur PCA)...
#
# === Évaluation du Meilleur XGBoost (RandomSearch) sur Test (PCA) ===
#
# 📊 Multilabel Evaluation Metrics:
# Nom :               : Test (Best XGB PCA)
# Subset accuracy     : 0.0070
# Hamming loss        : 0.2445
# Micro F1            : 0.7951
# Macro F1            : 0.6116
# Weighted F1         : 0.7811
# Micro ROC-AUC       : 0.8216
# Macro ROC-AUC       : 0.5877

# %%
# --- Valeurs de C à tester ---
# C=1.0 (moins de régularisation), C=0.5, C=0.1 (plus de régularisation)
C_values = [1.0, 0.5, 0.1]
results_l1 = []

print("🚀 Test de différentes forces de régularisation L1 pour Régression Logistique...")

for c_val in C_values:
    print(f"\n--- Test avec C = {c_val} ---")
    # Définit et entraîne le modèle
    l1_model_tuned = OneVsRestClassifier(
        LogisticRegression(
            penalty='l1',
            C=c_val,
            solver='liblinear',
            class_weight='balanced',
            max_iter=1000 # Augmenté pour convergence
        ),
        n_jobs=4 # Utilise 4 coeurs
    )
    l1_model_tuned.fit(X_train_raw, y_train)

    # Prédictions sur le set de validation (ou test, selon préférence)
    print("⚙️ Génération des prédictions (Validation)...")
    y_valid_pred_l1_tuned = l1_model_tuned.predict(X_valid_raw)
    y_valid_prob_l1_tuned = l1_model_tuned.predict_proba(X_valid_raw)

    # Évaluation sur le set de validation
    print(f"\n=== Évaluation LR L1 (C={c_val}) sur Validation ===")
    metrics = evaluate_multilabel_model(
        y_valid, y_valid_pred_l1_tuned, y_valid_prob_l1_tuned, f"Validation (LR L1 C={c_val})"
    )
    metrics['C'] = c_val # Ajoute C aux résultats
    results_l1.append(metrics)

# --- Afficher un résumé des résultats ---
print("\n=== Résumé des performances LR L1 sur Validation ===")
results_df_l1 = pd.DataFrame(results_l1)
# Affiche les colonnes pertinentes pour la comparaison
print(results_df_l1[['C', 'Macro F1', 'Micro F1', 'Macro ROC-AUC', 'Micro ROC-AUC', 'Hamming loss']].round(4))

# --- Optionnel: Ré-entraîner le meilleur C sur Train+Valid et évaluer sur Test ---
# Trouve le meilleur C basé sur le Macro F1 sur la validation
best_c_l1 = results_df_l1.loc[results_df_l1['Macro F1'].idxmax()]['C']
print(f"\n✅ Meilleur C trouvé basé sur Macro F1 (Validation) : {best_c_l1}")

# (Si souhaité, tu peux ajouter ici le code pour ré-entraîner avec le best_c_l1 sur
# np.vstack((X_train_raw, X_valid_raw)) et np.vstack((y_train, y_valid)),
# puis évaluer sur X_test_raw, y_test)
# Out:
# 🚀 Test de différentes forces de régularisation L1 pour Régression Logistique...
#
# --- Test avec C = 1.0 ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 12
#       9 print(f"\n--- Test avec C = {c_val} ---")
#      10 # Définit et entraîne le modèle
#      11 l1_model_tuned = OneVsRestClassifier(
# ---> 12     LogisticRegression(
#      13         penalty='l1',
#      14         C=c_val,
#      15         solver='liblinear',
#      16         class_weight='balanced',
#      17         max_iter=1000 # Augmenté pour convergence
#      18     ),
#      19     n_jobs=4 # Utilise 4 coeurs
#      20 )
#      21 l1_model_tuned.fit(X_train_raw, y_train)
#      23 # Prédictions sur le set de validation (ou test, selon préférence)
#
# NameError: name 'LogisticRegression' is not defined
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.15639878836228102, estimator__max_depth=7, estimator__n_estimators=120, estimator__reg_alpha=0.15601864044243652, estimator__reg_lambda=0.15599452033620265, estimator__subsample=0.6232334448672797; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.996884623716487, estimator__gamma=0.30874075481385826, estimator__learning_rate=0.1323306320976562, estimator__max_depth=7, estimator__n_estimators=335, estimator__reg_alpha=0.023062425041415757, estimator__reg_lambda=0.5247746602583891, estimator__subsample=0.7599443886861021; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.6186662652854461, estimator__gamma=0.4868777594207296, estimator__learning_rate=0.05655426808606085, estimator__max_depth=8, estimator__n_estimators=274, estimator__reg_alpha=0.6183860093330873, estimator__reg_lambda=0.38246199126716274, estimator__subsample=0.9932923543227152; total time= 2.4min
# [CV] END estimator__colsample_bytree=0.786705157299192, estimator__gamma=0.4299702033681603, estimator__learning_rate=0.14606150771755597, estimator__max_depth=3, estimator__n_estimators=266, estimator__reg_alpha=0.013264961159866528, estimator__reg_lambda=0.9422017556848528, estimator__subsample=0.8253152871382157; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.7541666010159664, estimator__gamma=0.007983126110107097, estimator__learning_rate=0.056178765124429805, estimator__max_depth=6, estimator__n_estimators=363, estimator__reg_alpha=0.034388521115218396, estimator__reg_lambda=0.9093204020787821, estimator__subsample=0.7035119926400067; total time= 4.7min
# [CV] END estimator__colsample_bytree=0.9757995766256756, estimator__gamma=0.4474136752138244, estimator__learning_rate=0.12957999576221704, estimator__max_depth=9, estimator__n_estimators=314, estimator__reg_alpha=0.5208342600258237, estimator__reg_lambda=0.9611720243493491, estimator__subsample=0.9378135394712606; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.8989280440549523, estimator__gamma=0.2698460661945399, estimator__learning_rate=0.12735023313276966, estimator__max_depth=3, estimator__n_estimators=351, estimator__reg_alpha=0.6070342476866847, estimator__reg_lambda=0.27599918202254337, estimator__subsample=0.718509402281633; total time= 1.6min
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.024808930346818074, estimator__max_depth=9, estimator__n_estimators=140, estimator__reg_alpha=0.9149596755437808, estimator__reg_lambda=0.8500385777897993, estimator__subsample=0.7797802696552814; total time= 4.6min
# [CV] END estimator__colsample_bytree=0.6381640465961645, estimator__gamma=0.18540912609913318, estimator__learning_rate=0.14376825053272146, estimator__max_depth=7, estimator__n_estimators=198, estimator__reg_alpha=0.5912977877077271, estimator__reg_lambda=0.27472179299006416, estimator__subsample=0.8244973703390804; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.8842651558743149, estimator__gamma=0.05544541040591566, estimator__learning_rate=0.09786730037315403, estimator__max_depth=5, estimator__n_estimators=162, estimator__reg_alpha=0.8957635956735194, estimator__reg_lambda=0.47537022318211175, estimator__subsample=0.8253102287905535; total time= 2.8min
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.13088347585556345, estimator__max_depth=9, estimator__n_estimators=270, estimator__reg_alpha=0.2030612247347694, estimator__reg_lambda=0.942853570557981, estimator__subsample=0.8395461865954144; total time= 3.8min
# [CV] END estimator__colsample_bytree=0.9533121035675474, estimator__gamma=0.16217251050263698, estimator__learning_rate=0.03441759094013467, estimator__max_depth=3, estimator__n_estimators=330, estimator__reg_alpha=0.906828441545754, estimator__reg_lambda=0.2721322493846353, estimator__subsample=0.8590760482165449; total time= 3.1min
# [CV] END estimator__colsample_bytree=0.6002081507981263, estimator__gamma=0.1762844281670845, estimator__learning_rate=0.07095625163160581, estimator__max_depth=8, estimator__n_estimators=236, estimator__reg_alpha=0.4848299713589832, estimator__reg_lambda=0.6924360328902703, estimator__subsample=0.7077649335194086; total time= 3.4min
# [CV] END estimator__colsample_bytree=0.7007129183301457, estimator__gamma=0.24862425294619273, estimator__learning_rate=0.07017566196335394, estimator__max_depth=3, estimator__n_estimators=180, estimator__reg_alpha=0.266781014275285, estimator__reg_lambda=0.9766149558326529, estimator__subsample=0.7644148053272926; total time= 1.9min
# [CV] END estimator__colsample_bytree=0.6132202931602193, estimator__gamma=0.1725356240133415, estimator__learning_rate=0.13687026894027277, estimator__max_depth=8, estimator__n_estimators=229, estimator__reg_alpha=0.5309345833171364, estimator__reg_lambda=0.44778316457309164, estimator__subsample=0.8211572356285312; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.0839308912122809, estimator__max_depth=3, estimator__n_estimators=354, estimator__reg_alpha=0.8031397563798959, estimator__reg_lambda=0.4703006344460384, estimator__subsample=0.9933692563579372; total time= 2.9min
# [CV] END estimator__colsample_bytree=0.759028808435009, estimator__gamma=0.25887567526374006, estimator__learning_rate=0.17754202118146561, estimator__max_depth=5, estimator__n_estimators=250, estimator__reg_alpha=0.5414479738275658, estimator__reg_lambda=0.6957843993450822, estimator__subsample=0.6914200087189198; total time= 1.7min
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.15639878836228102, estimator__max_depth=7, estimator__n_estimators=120, estimator__reg_alpha=0.15601864044243652, estimator__reg_lambda=0.15599452033620265, estimator__subsample=0.6232334448672797; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.9464704583099741, estimator__gamma=0.3005575058716044, estimator__learning_rate=0.1516145155592091, estimator__max_depth=8, estimator__n_estimators=357, estimator__reg_alpha=0.7219987722668247, estimator__reg_lambda=0.9385527090157502, estimator__subsample=0.6003115063364057; total time= 2.0min
# [CV] END estimator__colsample_bytree=0.6186662652854461, estimator__gamma=0.4868777594207296, estimator__learning_rate=0.05655426808606085, estimator__max_depth=8, estimator__n_estimators=274, estimator__reg_alpha=0.6183860093330873, estimator__reg_lambda=0.38246199126716274, estimator__subsample=0.9932923543227152; total time= 2.5min
# [CV] END estimator__colsample_bytree=0.786705157299192, estimator__gamma=0.4299702033681603, estimator__learning_rate=0.14606150771755597, estimator__max_depth=3, estimator__n_estimators=266, estimator__reg_alpha=0.013264961159866528, estimator__reg_lambda=0.9422017556848528, estimator__subsample=0.8253152871382157; total time= 1.3min
# [CV] END estimator__colsample_bytree=0.8650089137415928, estimator__gamma=0.15585553804470548, estimator__learning_rate=0.11401360423556216, estimator__max_depth=4, estimator__n_estimators=359, estimator__reg_alpha=0.18485445552552704, estimator__reg_lambda=0.9695846277645586, estimator__subsample=0.9100531293444458; total time= 2.4min
# [CV] END estimator__colsample_bytree=0.8650089137415928, estimator__gamma=0.15585553804470548, estimator__learning_rate=0.11401360423556216, estimator__max_depth=4, estimator__n_estimators=359, estimator__reg_alpha=0.18485445552552704, estimator__reg_lambda=0.9695846277645586, estimator__subsample=0.9100531293444458; total time= 2.3min
# [CV] END estimator__colsample_bytree=0.9757995766256756, estimator__gamma=0.4474136752138244, estimator__learning_rate=0.12957999576221704, estimator__max_depth=9, estimator__n_estimators=314, estimator__reg_alpha=0.5208342600258237, estimator__reg_lambda=0.9611720243493491, estimator__subsample=0.9378135394712606; total time= 2.2min
# [CV] END estimator__colsample_bytree=0.6661067756252009, estimator__gamma=0.007818203370596966, estimator__learning_rate=0.09468029614127392, estimator__max_depth=3, estimator__n_estimators=235, estimator__reg_alpha=0.005522117123602399, estimator__reg_lambda=0.8154614284548342, estimator__subsample=0.8827429375390468; total time= 1.5min
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.024808930346818074, estimator__max_depth=9, estimator__n_estimators=140, estimator__reg_alpha=0.9149596755437808, estimator__reg_lambda=0.8500385777897993, estimator__subsample=0.7797802696552814; total time= 5.1min
# [CV] END estimator__colsample_bytree=0.7531707499015159, estimator__gamma=0.4858560476945519, estimator__learning_rate=0.1797827648532168, estimator__max_depth=7, estimator__n_estimators=317, estimator__reg_alpha=0.23598491974895575, estimator__reg_lambda=0.25606832276132396, estimator__subsample=0.6161734358153725; total time= 1.9min
# [CV] END estimator__colsample_bytree=0.8842651558743149, estimator__gamma=0.05544541040591566, estimator__learning_rate=0.09786730037315403, estimator__max_depth=5, estimator__n_estimators=162, estimator__reg_alpha=0.8957635956735194, estimator__reg_lambda=0.47537022318211175, estimator__subsample=0.8253102287905535; total time= 3.0min
# [CV] END estimator__colsample_bytree=0.8779139732158818, estimator__gamma=0.44023391950762886, estimator__learning_rate=0.13487080962675865, estimator__max_depth=8, estimator__n_estimators=233, estimator__reg_alpha=0.45653457048291024, estimator__reg_lambda=0.2184404372168336, estimator__subsample=0.7666039791481465; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.8779139732158818, estimator__gamma=0.44023391950762886, estimator__learning_rate=0.13487080962675865, estimator__max_depth=8, estimator__n_estimators=233, estimator__reg_alpha=0.45653457048291024, estimator__reg_lambda=0.2184404372168336, estimator__subsample=0.7666039791481465; total time= 2.2min
# [CV] END estimator__colsample_bytree=0.6002081507981263, estimator__gamma=0.1762844281670845, estimator__learning_rate=0.07095625163160581, estimator__max_depth=8, estimator__n_estimators=236, estimator__reg_alpha=0.4848299713589832, estimator__reg_lambda=0.6924360328902703, estimator__subsample=0.7077649335194086; total time= 3.3min
# [CV] END estimator__colsample_bytree=0.6976502088991097, estimator__gamma=0.08414552108646528, estimator__learning_rate=0.05375284391461405, estimator__max_depth=3, estimator__n_estimators=279, estimator__reg_alpha=0.363629602379294, estimator__reg_lambda=0.9717820827209607, estimator__subsample=0.9849789179768444; total time= 2.7min
# [CV] END estimator__colsample_bytree=0.7007129183301457, estimator__gamma=0.24862425294619273, estimator__learning_rate=0.07017566196335394, estimator__max_depth=3, estimator__n_estimators=180, estimator__reg_alpha=0.266781014275285, estimator__reg_lambda=0.9766149558326529, estimator__subsample=0.7644148053272926; total time= 1.7min
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.0839308912122809, estimator__max_depth=3, estimator__n_estimators=354, estimator__reg_alpha=0.8031397563798959, estimator__reg_lambda=0.4703006344460384, estimator__subsample=0.9933692563579372; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.7595297769778212, estimator__gamma=0.40821593660969197, estimator__learning_rate=0.16966902499691025, estimator__max_depth=3, estimator__n_estimators=223, estimator__reg_alpha=0.5081987767407187, estimator__reg_lambda=0.6958128067908819, estimator__subsample=0.943343521925488; total time=  55.2s
# [CV] END estimator__colsample_bytree=0.7595297769778212, estimator__gamma=0.40821593660969197, estimator__learning_rate=0.16966902499691025, estimator__max_depth=3, estimator__n_estimators=223, estimator__reg_alpha=0.5081987767407187, estimator__reg_lambda=0.6958128067908819, estimator__subsample=0.943343521925488; total time= 1.3min
# [CV] END estimator__colsample_bytree=0.730383562080754, estimator__gamma=0.11012052378277415, estimator__learning_rate=0.15222990648760357, estimator__max_depth=9, estimator__n_estimators=246, estimator__reg_alpha=0.3486659872917294, estimator__reg_lambda=0.09617655109142076, estimator__subsample=0.9762093057958416; total time= 2.2min
# [CV] END estimator__colsample_bytree=0.9464704583099741, estimator__gamma=0.3005575058716044, estimator__learning_rate=0.1516145155592091, estimator__max_depth=8, estimator__n_estimators=357, estimator__reg_alpha=0.7219987722668247, estimator__reg_lambda=0.9385527090157502, estimator__subsample=0.6003115063364057; total time= 1.9min
# [CV] END estimator__colsample_bytree=0.996884623716487, estimator__gamma=0.30874075481385826, estimator__learning_rate=0.1323306320976562, estimator__max_depth=7, estimator__n_estimators=335, estimator__reg_alpha=0.023062425041415757, estimator__reg_lambda=0.5247746602583891, estimator__subsample=0.7599443886861021; total time= 1.9min
# [CV] END estimator__colsample_bytree=0.6186662652854461, estimator__gamma=0.4868777594207296, estimator__learning_rate=0.05655426808606085, estimator__max_depth=8, estimator__n_estimators=274, estimator__reg_alpha=0.6183860093330873, estimator__reg_lambda=0.38246199126716274, estimator__subsample=0.9932923543227152; total time= 2.5min
# [CV] END estimator__colsample_bytree=0.7541666010159664, estimator__gamma=0.007983126110107097, estimator__learning_rate=0.056178765124429805, estimator__max_depth=6, estimator__n_estimators=363, estimator__reg_alpha=0.034388521115218396, estimator__reg_lambda=0.9093204020787821, estimator__subsample=0.7035119926400067; total time= 4.7min
# [CV] END estimator__colsample_bytree=0.9757995766256756, estimator__gamma=0.4474136752138244, estimator__learning_rate=0.12957999576221704, estimator__max_depth=9, estimator__n_estimators=314, estimator__reg_alpha=0.5208342600258237, estimator__reg_lambda=0.9611720243493491, estimator__subsample=0.9378135394712606; total time= 2.0min
# [CV] END estimator__colsample_bytree=0.8989280440549523, estimator__gamma=0.2698460661945399, estimator__learning_rate=0.12735023313276966, estimator__max_depth=3, estimator__n_estimators=351, estimator__reg_alpha=0.6070342476866847, estimator__reg_lambda=0.27599918202254337, estimator__subsample=0.718509402281633; total time= 1.6min
# [CV] END estimator__colsample_bytree=0.6661067756252009, estimator__gamma=0.007818203370596966, estimator__learning_rate=0.09468029614127392, estimator__max_depth=3, estimator__n_estimators=235, estimator__reg_alpha=0.005522117123602399, estimator__reg_lambda=0.8154614284548342, estimator__subsample=0.8827429375390468; total time= 1.3min
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.024808930346818074, estimator__max_depth=9, estimator__n_estimators=140, estimator__reg_alpha=0.9149596755437808, estimator__reg_lambda=0.8500385777897993, estimator__subsample=0.7797802696552814; total time= 5.4min
# [CV] END estimator__colsample_bytree=0.7531707499015159, estimator__gamma=0.4858560476945519, estimator__learning_rate=0.1797827648532168, estimator__max_depth=7, estimator__n_estimators=317, estimator__reg_alpha=0.23598491974895575, estimator__reg_lambda=0.25606832276132396, estimator__subsample=0.6161734358153725; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.13088347585556345, estimator__max_depth=9, estimator__n_estimators=270, estimator__reg_alpha=0.2030612247347694, estimator__reg_lambda=0.942853570557981, estimator__subsample=0.8395461865954144; total time= 3.7min
# [CV] END estimator__colsample_bytree=0.8779139732158818, estimator__gamma=0.44023391950762886, estimator__learning_rate=0.13487080962675865, estimator__max_depth=8, estimator__n_estimators=233, estimator__reg_alpha=0.45653457048291024, estimator__reg_lambda=0.2184404372168336, estimator__subsample=0.7666039791481465; total time= 2.2min
# [CV] END estimator__colsample_bytree=0.9533121035675474, estimator__gamma=0.16217251050263698, estimator__learning_rate=0.03441759094013467, estimator__max_depth=3, estimator__n_estimators=330, estimator__reg_alpha=0.906828441545754, estimator__reg_lambda=0.2721322493846353, estimator__subsample=0.8590760482165449; total time= 2.8min
# [CV] END estimator__colsample_bytree=0.6976502088991097, estimator__gamma=0.08414552108646528, estimator__learning_rate=0.05375284391461405, estimator__max_depth=3, estimator__n_estimators=279, estimator__reg_alpha=0.363629602379294, estimator__reg_lambda=0.9717820827209607, estimator__subsample=0.9849789179768444; total time= 2.7min
# [CV] END estimator__colsample_bytree=0.6976502088991097, estimator__gamma=0.08414552108646528, estimator__learning_rate=0.05375284391461405, estimator__max_depth=3, estimator__n_estimators=279, estimator__reg_alpha=0.363629602379294, estimator__reg_lambda=0.9717820827209607, estimator__subsample=0.9849789179768444; total time= 2.3min
# [CV] END estimator__colsample_bytree=0.6132202931602193, estimator__gamma=0.1725356240133415, estimator__learning_rate=0.13687026894027277, estimator__max_depth=8, estimator__n_estimators=229, estimator__reg_alpha=0.5309345833171364, estimator__reg_lambda=0.44778316457309164, estimator__subsample=0.8211572356285312; total time= 2.2min
# [CV] END estimator__colsample_bytree=0.7595297769778212, estimator__gamma=0.40821593660969197, estimator__learning_rate=0.16966902499691025, estimator__max_depth=3, estimator__n_estimators=223, estimator__reg_alpha=0.5081987767407187, estimator__reg_lambda=0.6958128067908819, estimator__subsample=0.943343521925488; total time= 1.2min
# [CV] END estimator__colsample_bytree=0.730383562080754, estimator__gamma=0.11012052378277415, estimator__learning_rate=0.15222990648760357, estimator__max_depth=9, estimator__n_estimators=246, estimator__reg_alpha=0.3486659872917294, estimator__reg_lambda=0.09617655109142076, estimator__subsample=0.9762093057958416; total time= 2.5min
# [CV] END estimator__colsample_bytree=0.759028808435009, estimator__gamma=0.25887567526374006, estimator__learning_rate=0.17754202118146561, estimator__max_depth=5, estimator__n_estimators=250, estimator__reg_alpha=0.5414479738275658, estimator__reg_lambda=0.6957843993450822, estimator__subsample=0.6914200087189198; total time= 1.5min
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.15639878836228102, estimator__max_depth=7, estimator__n_estimators=120, estimator__reg_alpha=0.15601864044243652, estimator__reg_lambda=0.15599452033620265, estimator__subsample=0.6232334448672797; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.9464704583099741, estimator__gamma=0.3005575058716044, estimator__learning_rate=0.1516145155592091, estimator__max_depth=8, estimator__n_estimators=357, estimator__reg_alpha=0.7219987722668247, estimator__reg_lambda=0.9385527090157502, estimator__subsample=0.6003115063364057; total time= 2.0min
# [CV] END estimator__colsample_bytree=0.996884623716487, estimator__gamma=0.30874075481385826, estimator__learning_rate=0.1323306320976562, estimator__max_depth=7, estimator__n_estimators=335, estimator__reg_alpha=0.023062425041415757, estimator__reg_lambda=0.5247746602583891, estimator__subsample=0.7599443886861021; total time= 2.0min
# [CV] END estimator__colsample_bytree=0.786705157299192, estimator__gamma=0.4299702033681603, estimator__learning_rate=0.14606150771755597, estimator__max_depth=3, estimator__n_estimators=266, estimator__reg_alpha=0.013264961159866528, estimator__reg_lambda=0.9422017556848528, estimator__subsample=0.8253152871382157; total time= 1.3min
# [CV] END estimator__colsample_bytree=0.7541666010159664, estimator__gamma=0.007983126110107097, estimator__learning_rate=0.056178765124429805, estimator__max_depth=6, estimator__n_estimators=363, estimator__reg_alpha=0.034388521115218396, estimator__reg_lambda=0.9093204020787821, estimator__subsample=0.7035119926400067; total time= 4.6min
# [CV] END estimator__colsample_bytree=0.8650089137415928, estimator__gamma=0.15585553804470548, estimator__learning_rate=0.11401360423556216, estimator__max_depth=4, estimator__n_estimators=359, estimator__reg_alpha=0.18485445552552704, estimator__reg_lambda=0.9695846277645586, estimator__subsample=0.9100531293444458; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.8989280440549523, estimator__gamma=0.2698460661945399, estimator__learning_rate=0.12735023313276966, estimator__max_depth=3, estimator__n_estimators=351, estimator__reg_alpha=0.6070342476866847, estimator__reg_lambda=0.27599918202254337, estimator__subsample=0.718509402281633; total time= 1.9min
# [CV] END estimator__colsample_bytree=0.6661067756252009, estimator__gamma=0.007818203370596966, estimator__learning_rate=0.09468029614127392, estimator__max_depth=3, estimator__n_estimators=235, estimator__reg_alpha=0.005522117123602399, estimator__reg_lambda=0.8154614284548342, estimator__subsample=0.8827429375390468; total time= 1.6min
# [CV] END estimator__colsample_bytree=0.6381640465961645, estimator__gamma=0.18540912609913318, estimator__learning_rate=0.14376825053272146, estimator__max_depth=7, estimator__n_estimators=198, estimator__reg_alpha=0.5912977877077271, estimator__reg_lambda=0.27472179299006416, estimator__subsample=0.8244973703390804; total time= 1.9min
# [CV] END estimator__colsample_bytree=0.6381640465961645, estimator__gamma=0.18540912609913318, estimator__learning_rate=0.14376825053272146, estimator__max_depth=7, estimator__n_estimators=198, estimator__reg_alpha=0.5912977877077271, estimator__reg_lambda=0.27472179299006416, estimator__subsample=0.8244973703390804; total time= 1.9min
# [CV] END estimator__colsample_bytree=0.7531707499015159, estimator__gamma=0.4858560476945519, estimator__learning_rate=0.1797827648532168, estimator__max_depth=7, estimator__n_estimators=317, estimator__reg_alpha=0.23598491974895575, estimator__reg_lambda=0.25606832276132396, estimator__subsample=0.6161734358153725; total time= 1.6min
# [CV] END estimator__colsample_bytree=0.8842651558743149, estimator__gamma=0.05544541040591566, estimator__learning_rate=0.09786730037315403, estimator__max_depth=5, estimator__n_estimators=162, estimator__reg_alpha=0.8957635956735194, estimator__reg_lambda=0.47537022318211175, estimator__subsample=0.8253102287905535; total time= 2.6min
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.13088347585556345, estimator__max_depth=9, estimator__n_estimators=270, estimator__reg_alpha=0.2030612247347694, estimator__reg_lambda=0.942853570557981, estimator__subsample=0.8395461865954144; total time= 3.7min
# [CV] END estimator__colsample_bytree=0.9533121035675474, estimator__gamma=0.16217251050263698, estimator__learning_rate=0.03441759094013467, estimator__max_depth=3, estimator__n_estimators=330, estimator__reg_alpha=0.906828441545754, estimator__reg_lambda=0.2721322493846353, estimator__subsample=0.8590760482165449; total time= 3.1min
# [CV] END estimator__colsample_bytree=0.6002081507981263, estimator__gamma=0.1762844281670845, estimator__learning_rate=0.07095625163160581, estimator__max_depth=8, estimator__n_estimators=236, estimator__reg_alpha=0.4848299713589832, estimator__reg_lambda=0.6924360328902703, estimator__subsample=0.7077649335194086; total time= 3.8min
# [CV] END estimator__colsample_bytree=0.7007129183301457, estimator__gamma=0.24862425294619273, estimator__learning_rate=0.07017566196335394, estimator__max_depth=3, estimator__n_estimators=180, estimator__reg_alpha=0.266781014275285, estimator__reg_lambda=0.9766149558326529, estimator__subsample=0.7644148053272926; total time= 1.5min
# [CV] END estimator__colsample_bytree=0.6132202931602193, estimator__gamma=0.1725356240133415, estimator__learning_rate=0.13687026894027277, estimator__max_depth=8, estimator__n_estimators=229, estimator__reg_alpha=0.5309345833171364, estimator__reg_lambda=0.44778316457309164, estimator__subsample=0.8211572356285312; total time= 2.5min
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.0839308912122809, estimator__max_depth=3, estimator__n_estimators=354, estimator__reg_alpha=0.8031397563798959, estimator__reg_lambda=0.4703006344460384, estimator__subsample=0.9933692563579372; total time= 2.4min
# [CV] END estimator__colsample_bytree=0.730383562080754, estimator__gamma=0.11012052378277415, estimator__learning_rate=0.15222990648760357, estimator__max_depth=9, estimator__n_estimators=246, estimator__reg_alpha=0.3486659872917294, estimator__reg_lambda=0.09617655109142076, estimator__subsample=0.9762093057958416; total time= 2.1min
# [CV] END estimator__colsample_bytree=0.759028808435009, estimator__gamma=0.25887567526374006, estimator__learning_rate=0.17754202118146561, estimator__max_depth=5, estimator__n_estimators=250, estimator__reg_alpha=0.5414479738275658, estimator__reg_lambda=0.6957843993450822, estimator__subsample=0.6914200087189198; total time= 1.1min
